# %%
Problem 1: Smart Light Controller

""# Taking light name as input
light_name = input("Light Name: ")

# Taking action (ON/OFF) as input
action = input("Action: ")""
OUTPUT:-
print(light_name + " is " + action)

Problem 2: Employee ID Card System

""# Taking employee details as input
name = input("Employee Name: ")
emp_id = input("Employee ID: ")
department = input("Department: ")""
OUTPUT:-
print("Employee ID Card")
print("Name:", name)
print("ID:", emp_id)
print("Department:", department)

Problem 3: Mobile Contact Record 

""# Taking contact details as input
contact_name = input("Contact Name: ")
phone_number = input("Phone Number: ")""

OUTPUT:-
print("Contact Saved")
print("Name:", contact_name)
print("Phone:", phone_number)

Problem 4: Product Price Tag Generator

""# Taking product details as input
product_name = input("Product Name: ")
price = input("Price: ")""
OUTPUT:-
print("Product:", product_name)
print("Price: ₹" + price)

Problem 5: Movie Rating Display System

""# Taking movie details as input
movie_name = input("Movie Name: ")
rating = input("Rating: ")""
OUTPUT:-
print("Movie:", movie_name)
print("Rating:", rating, "/ 5")

Problem 6: Delivery Address Manager

""# Taking customer details as input
customer_name = input("Customer Name: ")
address = input("Address: ")""
OUTPUT:-
print("Delivery Details")
print("Customer:", customer_name)
print("Address:", address)
# Out:
#   Cell In[1], line 1
#     Problem 1: Smart Light Controller
#             ^
# SyntaxError: invalid syntax
